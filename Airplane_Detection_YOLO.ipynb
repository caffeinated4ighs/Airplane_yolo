# %%
 # !pip install ultralytics
# !pip install torch
from ultralytics import YOLO
import tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 6.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cd /content/drive/MyDrive/data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !yolo task=detect mode=train epochs=50 data=/content/drive/MyDrive/data/custom_air_data.yaml model=yolov8m.pt
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 292MB/s]
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('yolov8l.pt')
result = model.train()
type(result)
# Out:
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 234MB/s]
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mv /content/runs/detect/train /content/drive/MyDrive/results
